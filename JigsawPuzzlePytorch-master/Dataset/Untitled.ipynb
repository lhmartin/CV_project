# %%
import os, numpy as np
from time import time
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision
import torch

from PIL import Image
from random import shuffle

# %%
from JigsawImageLoader import DataLoader
import matplotlib.pyplot as plt

# %%
data_path = '../../data/train/'

txt_list = '../../train.txt'

# %%
train_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=torchvision.transforms.ToTensor()
    )

# %%
data_path = '../../data/train/train_images'
train_loader = DataLoader(data_path, txt_list)

# %%
#../../data/train/0

# %%
train_loader.__getitem__(0)
# Out:
# hello?
# <PIL.Image.Image image mode=RGB size=96x96 at 0x2B1228A17908>
# 32.0
# (tensor([[[[ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02],
#            [ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02],
#            [ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02],
#            ...,
#            [ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02],
#            [ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02],
#            [ 9.4554e-02,  9.4554e-02,  9.4554e-02,  ...,  9.4554e-02,
#              9.4554e-02,  9.4554e-02]],
#
#           [[ 1.3532e-01,  1.3532e-01,  1.3532e-01,  ...,  1.3532e-01,
#              1.3532e-01,  1.3532e-01],
#            [ 1.3532e-01,  1.3532e-01,  1.3532e-01,  ...,  1.3532e-01,
# ...

# %%
 for i, t in enumerate(train_loader):
        print(i)
        print(len(t))
        print(len(t[0]))
        print(t[1])
        print(len(t[2]))
        break
# Out:
# hello?
# <PIL.Image.Image image mode=RGB size=96x96 at 0x2B122837B048>
# 32.0
# 0
# 3
# 9
# 455
# 9

# %%
imageRGB_reshape = np.einsum('kij->ijk',t[0][0])
imageRGB_reshape.shape
# Out:
# (25, 25, 3)

# %%
plt.imshow(np.squeeze(imageRGB_reshape))

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8fe99e9a77ae> in <module>
# ----> 1 plt.plot(t[0])
#
# ~/.conda/envs/slime_env/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~/.conda/envs/slime_env/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...
